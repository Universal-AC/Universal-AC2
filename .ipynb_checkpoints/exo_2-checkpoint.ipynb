# %%
import tensorflow as tf

# %%
import datetime

# %%
# %load_ext tensorboard

# %%
mnist = tf.keras.datasets.mnist #importation des données + normalisation
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# %%
modele=tf.keras.Sequential()
modele.add(tf.keras.layers.Conv2D(16, (4, 4), activation='relu')) #32=dim espace de sortie, strides, prend les 28x28
modele.add(tf.keras.layers.MaxPooling2D((2, 2))) #reduction de la dimension spatiale en sortie de la couche de convolution, mise en commun
modele.add(tf.keras.layers.Flatten()) #écrasement en vecteur
modele.add(tf.keras.layers.Dense(100, activation='relu'))
modele.add(tf.keras.layers.Dense(10, activation='softmax')) #puis activation à 10 neurones puisque chiffres 1 à 10
opt = tf.keras.optimizers.SGD(lr=0.01)
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# %%
modele.compile(opt, loss)

# %%
log_dir="logs\\model\\"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
modele.fit(x_train, y_train, epochs=3, callbacks=[tensorboard_callback])
# Out:
# Train on 60000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.4905
# Epoch 2/3
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.2081
# Epoch 3/3
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.1558

# %%
print(modele.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  230500
# _________________________________________________________________
# dense_1 (Dense)              multiple                  1010
# =================================================================
# Total params: 231,782
# Trainable params: 231,782
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
modele.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.12628918989896773

# %%
x=modele.predict(x_test)

# %%
x.shape
# Out:
# (10000, 10)

# %%
x
# Out:
# array([[2.16932985e-05, 4.07493097e-08, 6.72984985e-04, ...,
#         9.99054611e-01, 6.83336202e-06, 2.21759346e-05],
#        [2.07763114e-05, 2.70659977e-04, 9.93774056e-01, ...,
#         2.31281341e-10, 5.00716269e-04, 2.73890511e-11],
#        [6.77380813e-05, 9.88179207e-01, 4.40431992e-03, ...,
#         3.29973083e-03, 2.05388526e-03, 7.38024100e-05],
#        ...,
#        [2.92855248e-06, 4.70896211e-08, 6.37074322e-07, ...,
#         1.21450146e-04, 6.72333292e-04, 4.44893772e-03],
#        [2.06619181e-04, 3.74945921e-06, 8.96412621e-06, ...,
#         7.64254821e-07, 7.25849997e-03, 1.69196971e-06],
#        [5.02208786e-06, 1.36156164e-09, 7.01564932e-05, ...,
#         1.54165042e-10, 1.75086271e-07, 3.67847486e-09]], dtype=float32)

# %%
r=tf.keras.metrics.SparseCategoricalAccuracy()

# %%
r(y_test, x)
# Out:
# <tf.Tensor: id=13322, shape=(), dtype=float32, numpy=0.963>

# %%
# %tensorboard --logdir logs/model
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 23936.
